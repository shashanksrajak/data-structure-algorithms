# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self, value):
        new_node = Node(value)
        self.head = new_node
        self.length = 1

    def append(self, value):
        new_node = Node(value)
        if self.length == 0:
            self.head = new_node
        else:
            current = self.head
            while current.next is not None:
                current = current.next
            current.next = new_node
        self.length += 1
        return True
    
    def print_list(self):
        temp = self.head
        while temp is not None:
            print(temp.value)
            temp = temp.next    
            
    def make_empty(self):
        self.head = None
        self.length = 0

    def reverse_between(self, start_index, end_index):
        prev = None
        current = self.head
        after = self.head.next
        index = 0
        
        first = None
        first_prev = None
    
        while current:
            print("index", index)
            print("after", after)
            
            if index == start_index:
                first = current
                if index == 0:
                    first_prev = self.head
                else:
                    first_prev = prev
                
            if index >= start_index and index < end_index:
                temp = after
                after = after.next
                temp.next = current
        
                prev = current
                current = temp
            
            elif index == end_index:
                last = current
                first_prev.next = last
                first.next = after
                print("last", last)
                print("first_prev", first_prev)
                return
            else:
                prev = current
                current = current.next
                after = after.next
            
            index += 1

# %%
linked_list = LinkedList(1)
linked_list.append(2)
linked_list.append(3)
linked_list.append(4)
linked_list.append(5)

# print("Original linked list: ")
linked_list.print_list()

# Reverse a sublist within the linked list
linked_list.reverse_between(2, 4)
print("Reversed sublist (2, 4): ")
linked_list.print_list()
# Out:
# 1
# 2
# 3
# 4
# 5
# index 0
# after <__main__.Node object at 0x10af69310>
# index 1
# after <__main__.Node object at 0x10af691d0>
# index 2
# after <__main__.Node object at 0x10653bbb0>
# index 3
# after <__main__.Node object at 0x106538050>
# index 4
# after None
# last <__main__.Node object at 0x106538050>
# first_prev <__main__.Node object at 0x10af69310>
# Reversed sublist (2, 4):
# 1
# 2
# 5
# 4
# 3

# %%
linked_list = LinkedList(1)
linked_list.append(2)
linked_list.append(3)
linked_list.append(4)
linked_list.append(5)

print("Original linked list: ")
linked_list.print_list()

# Reverse a sublist within the linked list
linked_list.reverse_between(2, 4)
print("Reversed sublist (2, 4): ")
linked_list.print_list()

# Reverse another sublist within the linked list
linked_list.reverse_between(0, 4)
print("Reversed entire linked list: ")
linked_list.print_list()

# Reverse a sublist of length 1 within the linked list
linked_list.reverse_between(3, 3)
print("Reversed sublist of length 1 (3, 3): ")
linked_list.print_list()

# Reverse an empty linked list
empty_list = LinkedList(0)
empty_list.make_empty()
empty_list.reverse_between(0, 0)
print("Reversed empty linked list: ")
empty_list.print_list()
# Out:
# Original linked list:
# 1
# 2
# 3
# 4
# 5
# index 0
# after <__main__.Node object at 0x10ad08e10>
# index 1
# after <__main__.Node object at 0x10ad08cd0>
# index 2
# after <__main__.Node object at 0x10653b490>
# index 3
# after <__main__.Node object at 0x10653b820>
# index 4
# after None
# last <__main__.Node object at 0x10653b820>
# first_prev <__main__.Node object at 0x10ad08e10>
# Reversed sublist (2, 4):
# 1
# 2
# 5
# 4
# 3
# index 0
# after <__main__.Node object at 0x10ad08e10>
# index 1
# after <__main__.Node object at 0x10653b820>
# index 2
# after <__main__.Node object at 0x10653b490>
# index 3
# after <__main__.Node object at 0x10ad08cd0>
# index 4
# after None
# last <__main__.Node object at 0x10ad08cd0>
# first_prev <__main__.Node object at 0x10a81aba0>
# Reversed entire linked list:
# 1
# index 0
# after None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 21
#      18 linked_list.print_list()
#      20 # Reverse a sublist of length 1 within the linked list
# ---> 21 linked_list.reverse_between(3, 3)
#      22 print("Reversed sublist of length 1 (3, 3): ")
#      23 linked_list.print_list()
#
# Cell In[50], line 72, in LinkedList.reverse_between(self, start_index, end_index)
#      70     prev = current
#      71     current = current.next
# ---> 72     after = after.next
#      74 index += 1
#
# AttributeError: 'NoneType' object has no attribute 'next'
